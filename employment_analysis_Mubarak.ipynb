# %% [markdown]
# #  data description

# %% [markdown]
# عدد العاملين (السعوديين - الغير سعوديين) تفصيليا حسب حجم المنشأة (متناهية الصغر, صغيرة, متوسطة, وكبيرة باستخدام تصنيف منشآت) والنشاط الاقتصادي (وذلك باستخدام التصنيف الوطني للأنشطة الاقتصادية - المستوى الاول والثاني والسادس) في كل منطقة جغرافية.

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import openpyxl
import os

# %% [markdown]
# # Import data

# %% [markdown]
# ## 2022

# %%
Q1_2022 = os.path.join('data','2022','Number Of Employees 2022 - Q1.xlsx')
Q2_2022 = os.path.join('data','2022','Number Of Employees 2022 - Q2.xlsx')
Q3_2022 = os.path.join('data','2022','Number Of Employees 2022 - Q3.xlsx')
Q4_2022 = os.path.join('data','2022','Number Of Employees 2022 - Q4.xlsx')

# %% [markdown]
# ## 2023

# %%
Q1_2023 = os.path.join('data','2023','Number Of Employees 2023 - Q1.xlsx')
Q2_2023 = os.path.join('data','2023','Number Of Employees 2023 - Q2.xlsx')
Q3_2023 = os.path.join('data','2023','Number Of Employees 2023 - Q3.xlsx')
Q4_2023 = os.path.join('data','2023','Number Of Employees 2023 - Q4.xlsx')

# %% [markdown]
# ## 2024

# %%
Q1_2024 = os.path.join('data','2024','Number Of Employees 2024 - Q1.xlsx')
Q2_2024 = os.path.join('data','2024','Number Of Employees 2024 - Q2.xlsx')
Q3_2024 = os.path.join('data','2024','Number Of Employees 2024 - Q3.xlsx')

# %% [markdown]
# # Read Data

# %% [markdown]
# ## 2022

# %%
df_2022_Q1 = pd.read_excel(Q1_2022)
df_2022_Q2 = pd.read_excel(Q2_2022)
df_2022_Q3 = pd.read_excel(Q3_2022)
df_2022_Q4 = pd.read_excel(Q4_2022)

# %%
print("\ndf_2022_Q1:")
print(df_2022_Q1.shape)
print("\ndf_2022_Q2:")
print(df_2022_Q2.shape)
print("\ndf_2022_Q3:")
print(df_2022_Q3.shape)
print("\ndf_2022_Q4:")
print(df_2022_Q4.shape)
# Out:
# df_2022_Q1:
# (2803, 14)
#
# df_2022_Q2:
# (2800, 14)
#
# df_2022_Q3:
# (2766, 14)
#
# df_2022_Q4:
# (2761, 14)

# %% [markdown]
# ## 2023

# %%
df_2023_Q1 = pd.read_excel(Q1_2023)
df_2023_Q2 = pd.read_excel(Q2_2023)
df_2023_Q3 = pd.read_excel(Q3_2023)
df_2023_Q4 = pd.read_excel(Q4_2023)

# %%
print("\ndf_2023_Q1:")
print(df_2022_Q1.shape)
print("\ndf_2023_Q2:")
print(df_2022_Q2.shape)
print("\ndf_2023_Q3:")
print(df_2022_Q3.shape)
print("\ndf_2023_Q4:")
print(df_2022_Q4.shape)
# Out:
# df_2023_Q1:
# (2803, 14)
#
# df_2023_Q2:
# (2800, 14)
#
# df_2023_Q3:
# (2766, 14)
#
# df_2023_Q4:
# (2761, 14)

# %% [markdown]
# ## 2024

# %%
df_2024_Q1 = pd.read_excel(Q1_2024)
df_2024_Q2 = pd.read_excel(Q2_2024)
df_2024_Q3 = pd.read_excel(Q3_2024)

# %%
print("df_2024_Q1:")
print(df_2024_Q1.shape)
print("\ndf_2024_Q2:")
print(df_2024_Q2.shape)
print("\ndf_2024_Q3:")
print(df_2024_Q3.shape)
# Out:
# df_2024_Q1:
# (2830, 14)
#
# df_2024_Q2:
# (12778, 15)
#
# df_2024_Q3:
# (12861, 15)

# %% [markdown]
# # Convert column names to English

# %%
dfs = [df_2024_Q1, df_2024_Q2, df_2024_Q3,
       df_2023_Q1, df_2023_Q2, df_2023_Q3,df_2023_Q4,
       df_2022_Q1, df_2022_Q2, df_2022_Q3, df_2022_Q4]

# %%
trans_col_dict = {
    "المنطقة": "region" ,
    "الربع": "Q",
    "السنة": "year" ,
    "حجم المنشأة":"size",
    "عدد المنشآت": "Number_Of_Establishments" ,
    "عدد العاملين السعوديين": "Number_Of_Saudis",
    "عدد السعوديين (ذكور)":"Number_Of_Male_Saudis",
    "عدد السعوديين (إناث)": "Number_Of_Female_Saudis",
    "عدد العاملين الغير سعوديين":"Number_Of_Nonsaudis" ,
    "عدد الغير سعوديين (ذكور)":"Number_Of_Male_Nonaudis",
    "عدد الغير سعوديين (إناث)": "Number_Of_Female_Nonaudis",
    "النشاط الاقتصادي - المستوى الثاني":"Economic_Activity",
    "النشاط الاقتصادي":"Economic_Activity",
    "عدد السعوديات (إناث)": "Number_Of_Female_Saudis",
    "عدد العاملين الأجانب":"Number_Of_Nonsaudis" ,
    "عدد الأجانب (ذكور)":"Number_Of_Male_Nonaudis",
    "عدد الأجنبيات (إناث)": "Number_Of_Female_Nonaudis",

}

# %%
# create function that takes dataframe and convert all columns to english
def arabic_to_english_column_names(df):
  df.rename(columns=trans_col_dict, inplace=True)
  return df

# %%
for df in dfs:
  arabic_to_english_column_names(df)

# %% [markdown]
# # EDA

# %% [markdown]
# ## dataframes overview

# %%
pd.set_option("display.max_rows", None) # Show all rows

# %%
df_2024= pd.concat([df_2024_Q1, df_2024_Q2, df_2024_Q3], ignore_index=True)
df_2023= pd.concat([df_2023_Q1, df_2023_Q2, df_2023_Q3, df_2023_Q4], ignore_index=True)
df_2022= pd.concat([df_2022_Q1, df_2022_Q2, df_2022_Q3, df_2022_Q4], ignore_index=True)

# %%
df_2024.shape, df_2023.shape, df_2022.shape
# Out:
# ((28469, 16), (11100, 14), (11130, 14))

# %%
df_2022.head()
# Out:
#    year  Q           region  \
# 0  2022  1  المنطقة الشرقية
# 1  2022  1  المنطقة الشرقية
# 2  2022  1  المنطقة الشرقية
# 3  2022  1  المنطقة الشرقية
# 4  2022  1     منطقة الباحة
#
#                                    Economic_Activity           size  \
# 0  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...          صغيرة
# 1  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...          كبيرة
# 2  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...  متناهية الصغر
# 3  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...         متوسطة
# 4  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...  متناهية الصغر
#
#    Number_Of_Establishments  Number_Of_Saudis  Number_Of_Male_Saudis  \
# 0                        50               276                    132
# 1                         1               273                    258
# 2                       128                96                     47
# 3                         7               184                    119
# 4                         2                 0                      0
#
#    Number_Of_Female_Saudis  Number_Of_Nonsaudis  Number_Of_Male_Nonaudis  \
# 0                      144                  462                      451
# 1                       15                  334                      333
# 2                       49                  198                      194
# 3                       65                  392                      390
# 4                        0                    6                        6
#
#    Number_Of_Female_Nonaudis  Unnamed: 12  \
# 0                         11          NaN
# 1                          1          NaN
# 2                          4          NaN
# 3                          2          NaN
# 4                          0          NaN
#
#                                          Unnamed: 13
# 0                                                NaN
# 1  اخلاء مسؤولية:\n - تمت معالجة البيانات بأقصى ق...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df_2023.head()
# Out:
#    year  Q           region  \
# 0  2023  1  المنطقة الشرقية
# 1  2023  1  المنطقة الشرقية
# 2  2023  1  المنطقة الشرقية
# 3  2023  1  المنطقة الشرقية
# 4  2023  1     منطقة الباحة
#
#                                    Economic_Activity           size  \
# 0  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...          صغيرة
# 1  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...          كبيرة
# 2  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...  متناهية الصغر
# 3  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...         متوسطة
# 4  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...  متناهية الصغر
#
#    Number_Of_Establishments  Number_Of_Saudis  Number_Of_Male_Saudis  \
# 0                        54               320                    137
# 1                         1               221                    207
# 2                       184               122                     65
# 3                         6               239                    130
# 4                         7                 2                      2
#
#    Number_Of_Female_Saudis  Number_Of_Nonsaudis  Number_Of_Male_Nonaudis  \
# 0                      183                  523                      516
# 1                       14                  213                      212
# 2                       57                  287                      285
# 3                      109                  329                      326
# 4                        0                   13                       13
#
#    Number_Of_Female_Nonaudis  Unnamed: 12  \
# 0                          7          NaN
# 1                          1          NaN
# 2                          2          NaN
# 3                          3          NaN
# 4                          0          NaN
#
#                                          Unnamed: 13
# 0                                                NaN
# 1  اخلاء مسؤولية:\n - تمت معالجة البيانات بأقصى ق...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df_2024.head()
# Out:
#    year  Q           region  \
# 0  2024  1  المنطقة الشرقية
# 1  2024  1  المنطقة الشرقية
# 2  2024  1  المنطقة الشرقية
# 3  2024  1  المنطقة الشرقية
# 4  2024  1     منطقة الباحة
#
#                                    Economic_Activity           size  \
# 0  الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإ...  متناهية الصغر
# 1  الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإ...          صغيرة
# 2  الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإ...         متوسطة
# 3  الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإ...          كبيرة
# 4  الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإ...  متناهية الصغر
#
#    Number_Of_Establishments  Number_Of_Saudis  Number_Of_Male_Saudis  \
# 0                        57                29                     14
# 1                        13               146                     94
# 2                         1                43                     43
# 3                         2               827                    624
# 4                         8                 1                      1
#
#    Number_Of_Female_Saudis  Number_Of_Nonsaudis  Number_Of_Male_Nonaudis  \
# 0                       15                   81                       81
# 1                       52                   75                       73
# 2                        0                    7                        7
# 3                      203                  283                      274
# 4                        0                   18                       18
#
#    Number_Of_Female_Nonaudis  Unnamed: 12  \
# 0                          0          NaN
# 1                          2          NaN
# 2                          0          NaN
# 3                          9          NaN
# 4                          0          NaN
#
#                                          Unnamed: 13 المدينة Unnamed: 14
# 0                                                NaN     NaN         NaN
# 1  اخلاء مسؤولية:\n - تمت معالجة البيانات بأقصى ق...     NaN         NaN
# 2                                                NaN     NaN         NaN
# 3                                                NaN     NaN         NaN
# 4                                                NaN     NaN         NaN

# %%
df_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28469 entries, 0 to 28468
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       28469 non-null  int64
#  1   Q                          28469 non-null  int64
#  2   region                     28469 non-null  object
#  3   Economic_Activity          28469 non-null  object
#  4   size                       28469 non-null  object
#  5   Number_Of_Establishments   28469 non-null  int64
#  6   Number_Of_Saudis           28469 non-null  int64
#  7   Number_Of_Male_Saudis      28469 non-null  int64
#  8   Number_Of_Female_Saudis    28469 non-null  int64
#  9   Number_Of_Nonsaudis        28469 non-null  int64
#  10  Number_Of_Male_Nonaudis    28469 non-null  int64
#  11  Number_Of_Female_Nonaudis  28469 non-null  int64
#  12  Unnamed: 12                0 non-null      float64
#  13  Unnamed: 13                1 non-null      object
#  14  المدينة                    25639 non-null  object
#  15  Unnamed: 14                2 non-null      object
# dtypes: float64(1), int64(9), object(6)
# memory usage: 3.5+ MB

# %%
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11100 entries, 0 to 11099
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       11100 non-null  int64
#  1   Q                          11100 non-null  int64
#  2   region                     11100 non-null  object
#  3   Economic_Activity          11100 non-null  object
#  4   size                       11100 non-null  object
#  5   Number_Of_Establishments   11100 non-null  int64
#  6   Number_Of_Saudis           11100 non-null  int64
#  7   Number_Of_Male_Saudis      11100 non-null  int64
#  8   Number_Of_Female_Saudis    11100 non-null  int64
#  9   Number_Of_Nonsaudis        11100 non-null  int64
#  10  Number_Of_Male_Nonaudis    11100 non-null  int64
#  11  Number_Of_Female_Nonaudis  11100 non-null  int64
#  12  Unnamed: 12                0 non-null      float64
#  13  Unnamed: 13                4 non-null      object
# dtypes: float64(1), int64(9), object(4)
# memory usage: 1.2+ MB

# %%
df_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28469 entries, 0 to 28468
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       28469 non-null  int64
#  1   Q                          28469 non-null  int64
#  2   region                     28469 non-null  object
#  3   Economic_Activity          28469 non-null  object
#  4   size                       28469 non-null  object
#  5   Number_Of_Establishments   28469 non-null  int64
#  6   Number_Of_Saudis           28469 non-null  int64
#  7   Number_Of_Male_Saudis      28469 non-null  int64
#  8   Number_Of_Female_Saudis    28469 non-null  int64
#  9   Number_Of_Nonsaudis        28469 non-null  int64
#  10  Number_Of_Male_Nonaudis    28469 non-null  int64
#  11  Number_Of_Female_Nonaudis  28469 non-null  int64
#  12  Unnamed: 12                0 non-null      float64
#  13  Unnamed: 13                1 non-null      object
#  14  المدينة                    25639 non-null  object
#  15  Unnamed: 14                2 non-null      object
# dtypes: float64(1), int64(9), object(6)
# memory usage: 3.5+ MB

# %% [markdown]
# ## Relevent

# %%
# drop المدينة
# drop unnamed columns
df_2022.drop(columns=["Unnamed: 12","Unnamed: 13"],inplace=True)
df_2023.drop(columns=["Unnamed: 12","Unnamed: 13"],inplace=True)
df_2024.drop(columns=["Unnamed: 12","Unnamed: 13","Unnamed: 14","المدينة"],inplace=True)

# %% [markdown]
# ## Deep analysis

# %% [markdown]
# ## Add necessary columns

# %%
df = pd.concat([df_2022, df_2023, df_2024], ignore_index=True)

# %%
df['total_employees'] = df['Number_Of_Saudis'] + df['Number_Of_Nonsaudis']

# %%
df['size'].value_counts().sort_values(ascending=False)
# Out:
# size
# متناهية الصغر    22268
# صغيرة            15666
# متوسطة            8506
# كبيرة             4259
# Name: count, dtype: int64

# %%
df['region'].value_counts().sort_values(ascending=False)
# Out:
# region
# منطقة الرياض             7488
# المنطقة الشرقية          6741
# منطقة مكة المكرمة        5890
# منطقة عسير               4528
# منطقة القصيم             4335
# منطقة المدينة المنورة    3819
# منطقة جازان              3651
# منطقة تبوك               2843
# منطقة نجران              2549
# منطقة حائل               2449
# منطقة الجوف              2196
# منطقة الباحة             2193
# منطقة الحدود الشمالية    2017
# Name: count, dtype: int64

# %%
df['Economic_Activity'].value_counts().sort_values(ascending=False)
# Out:
# Economic_Activity
# تشييد المباني                                                                                      1220
# تجارة التجزئة، باستثناء المركبات ذات المحركات والدراجات النارية                                    1103
# أنشطة التشييد المتخصصة                                                                             1080
# أنشطة خدمات الأطعمة والمشروبات                                                                     1063
# صنع منتجات المعادن اللافلزية الأخرى                                                                1059
# الصحة البشرية                                                                                      1048
# النقل البري و النقل عبر الأنابيب                                                                   1047
# أنشطة تقديم الخدمات للمباني وتجميل المواقع                                                         1013
# تجارة الجملة ، باستثناء المركبات ذات المحركات والدراجات النارية                                    1005
# الهندسة المدنية                                                                                     987
# صُنع المنتجات الغذائية                                                                              987
# تجارة الجملة والتجزئة ، وإصلاح المركبات ذات المحركات والدراجات النارية                              934
# أنشطة زراعة المحاصيل والإنتاج الحيواني والصيد والخدمات المتصلة                                      931
# صنع منتجات المعادن المشكلة ( باستثناء الآلات والمعدات )                                             888
# التعليم                                                                                             877
# الإقامة                                                                                             853
# أنشطة العمل الاجتماعي، دون إقامة                                                                    847
# غير معرف                                                                                            828
# إصلاح وتركيب الآلات والمعدات                                                                        819
# التخزين وأنشطة الدعم للنقل                                                                          805
# أنشطة الخدمات الشخصية الأخرى                                                                        797
# الأنشطة الإيجارية                                                                                   782
# صُنع الملبوسات                                                                                      768
# أنشطة المعمارية والهندسية ، والاختبارات الفنية والتحليل                                             761
# الأنشطة الأخرى للتعدين واستغلال المحاجر                                                             752
# صُنع الخشب ومنتجات الخشب والفلين ، باستثناء الأثاث ، صُنع أصناف من القش ومواد الضفر                 742
# صنع الأثاث                                                                                          730
# الأنشطة العقارية                                                                                    729
# صُنع المواد الكيميائية والمنتجات الكيميائية                                                         722
# تجميع المياه ومعالجتها وتوصيلها                                                                     715
# أنشطة الاستخدام                                                                                     709
# الأنشطة الإدارية للمكاتب ، وأنشطة الدعم للمكاتب وغير ذلك من أنشطة الدعم للأعمال                     700
# صُنع المشروبات                                                                                      694
# إصلاح أجهزة الحاسوب والسلع الشخصية والمنزلية                                                        693
# صنع الفلزات القاعدية                                                                                687
# صنع منتجات المطاط واللدائن                                                                          640
# الأنشطة الرياضية وأنشطة التسلية والترفيه                                                            636
# أبحاث الإعلان والسوق                                                                                627
# صُنع المنسوجات                                                                                      608
# أنشطة جمع النفايات ومعالجتها وتصريفها ، واسترجاع المواد                                             584
# أنشطة المنظمات ذات العضوية                                                                          576
# توصيل الكهرباء والغاز والبخار وتكييف الهواء                                                         560
# صنع المعدات الكهربائية                                                                              553
# الصرف الصحي                                                                                         553
# صُنع الورق ومنتجات الورق                                                                            540
# وكالات السفر ومشغّلو الجولات السياحية وخدمات الحجز والأنشطة المتصلة بها                             535
# الصناعة التحويلية الأخرى                                                                            524
# الأنشطة القانونية وأنشطة المحاسبة                                                                   523
# الطباعة واستنساخ وسائط الأعلام المسجّلة                                                             520
# صناعة الآلات والمعدات غير المصنفة في موضع أخر                                                       510
# أنشطة الأمن والتحقيقات                                                                              503
# أنشطة الخدمات المالية ، فيما عدا تمويل التأمين وصناديق المعاشات                                     485
# أنشطة البرمجة الحاسوبية والخبرة الاستشارية وما يتصل بها من أنشطة                                    483
# الأنشطة المهنية والعلمية والتقنية الأخرى                                                            467
# الاتصالات                                                                                           458
# الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإلزامي                                                 444
# صيد الأسماك وتربية المائيات                                                                         420
# صناعة المركبات ذات المحركات والمركبات المقطورة ونصف المقطورة                                        416
# صنع المنتجات الصيدلانية الأساسية والمستحضرات الصيدلانية                                             413
# صنع الحواسيب والمنتجات الإلكترونية والبصرية                                                         412
# الأنشطة البيطرية                                                                                    411
# أنشطة خدمات دعم التعدين                                                                             395
# أنشطة المكاتب الرئيسية، والأنشطة الاستشارية في مجال الإدارة                                         387
# أنشطة النشر                                                                                         377
# أنشطة البريد ونقل الرسائل والطرود بواسطة مندوبين                                                    371
# النقل الجوي                                                                                         371
# النقل المائي                                                                                        365
# تعدين ركازات الفلزات                                                                                361
# أنشطة خدمات المعلومات                                                                               354
# صنع فحم الكوك والمنتجات النفطية المكررة                                                             350
# الرعاية مع الإقامة                                                                                  345
# صُنع المنتجات الجلدية والمنتجات ذات الصلة                                                           326
# الأنشطة المساعدة لأنشطة الخدمات المالية وأنشطة التأمين                                              314
# صناعة معدات النقل الأخرى                                                                            309
# الأنشطة الإبداعية والفنون وأنشطة الترفيه                                                            269
# أنشطة المكتبات والمحفوظات والمتاحف والأنشطة الثقافية الأخرى                                         267
# البحث والتطوير في المجال العلمي                                                                     256
# تمويل التأمين وإعادة التأمين وصناديق المعاشات التقاعدية باستثناء الضمان الاجتماعي الإلزامي          217
# استخراج النفط الخام والغاز الطبيعي                                                                  210
# الحراجة وقطع الأخشاب                                                                                209
# أنشطة البرمجة والإذاعة                                                                              204
# تعدين الفحم والليغنيت                                                                               155
# أنشطة إنتاج الأفلام والفيديو والبرامج التليفزيونية والتسجيلات الصوتية ونشر الموسيقى                 149
# أنشطة المعالجة وخدمات إدارة النفايات الأخرى                                                         140
# أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل المنزلي                                              133
# الأنشطة غير المتميزة لإنتاج السلع والخدمات التي تقوم بها الأسر المعيشية الخاصة لإستعمالها الخاص      60
# أنشطة المنظمات والهيئات غير الخاضعة للولاية القضائية الوطنية                                         22
# صُنع منتجات التبغ                                                                                     4
# أنشطة انتاج الأفلام والبرامج التلفزيونية والتسجيلات الصوتية والموسيقية                                3
# Name: count, dtype: int64

# %%
year_group = df.groupby(['year','Q'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum()

# %%
activity_based_on_size = df.groupby(['size', 'Economic_Activity'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum()

# %%
activity_based_on_size['saudis_percentage'] = (activity_based_on_size['Number_Of_Saudis'] / activity_based_on_size['total_employees'])
activity_based_on_size['nonsaudis_percentage'] = (activity_based_on_size['Number_Of_Nonsaudis'] / activity_based_on_size['total_employees'])

# %%
activity_based_on_size.head()
# Out:
#                                                           Number_Of_Establishments  \
# size  Economic_Activity
# صغيرة أبحاث الإعلان والسوق                                                   13737
#       أنشطة إنتاج الأفلام والفيديو والبرامج التليفزيو...                       448
#       أنشطة الأمن والتحقيقات                                                  1386
#       أنشطة الاستخدام                                                         3881
#       أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                        27
#
#                                                           Number_Of_Saudis  \
# size  Economic_Activity
# صغيرة أبحاث الإعلان والسوق                                           73648
#       أنشطة إنتاج الأفلام والفيديو والبرامج التليفزيو...              3257
#       أنشطة الأمن والتحقيقات                                         21243
#       أنشطة الاستخدام                                                20628
#       أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                26
#
#                                                           Number_Of_Male_Saudis  \
# size  Economic_Activity
# صغيرة أبحاث الإعلان والسوق                                                30905
#       أنشطة إنتاج الأفلام والفيديو والبرامج التليفزيو...                   1607
#       أنشطة الأمن والتحقيقات                                              18336
#       أنشطة الاستخدام                                                      8144
#       أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                      0
#
#                                                           Number_Of_Female_Saudis  \
# size  Economic_Activity
# صغيرة أبحاث الإعلان والسوق                                                  42743
#       أنشطة إنتاج الأفلام والفيديو والبرامج التليفزيو...                     1650
#       أنشطة الأمن والتحقيقات                                                 2907
#       أنشطة الاستخدام                                                       12484
#       أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                       26
#
#                                                           Number_Of_Nonsaudis  \
# size  Economic_Activity
# صغيرة أبحاث الإعلان والسوق                                             105860
#       أنشطة إنتاج الأفلام والفيديو والبرامج التليفزيو...                 3238
#       أنشطة الأمن والتحقيقات                                             3482
#       أنشطة الاستخدام                                                   29908
#       أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                  213
#
#                                                           Number_Of_Male_Nonaudis  \
# size  Economic_Activity
# صغيرة أبحاث الإعلان والسوق                                                 100755
#       أنشطة إنتاج الأفلام والفيديو والبرامج التليفزيو...                     2923
#       أنشطة الأمن والتحقيقات                                                 3387
#       أنشطة الاستخدام                                                       20679
#       أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                      213
#
#                                                           Number_Of_Female_Nonaudis  \
# size  Economic_Activity
# صغيرة أبحاث الإعلان والسوق                                                     5105
#       أنشطة إنتاج الأفلام والفيديو والبرامج التليفزيو...                        315
#       أنشطة الأمن والتحقيقات                                                     95
#       أنشطة الاستخدام                                                          9229
#       أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                          0
#
#                                                           total_employees  \
# size  Economic_Activity
# صغيرة أبحاث الإعلان والسوق                                         179508
#       أنشطة إنتاج الأفلام والفيديو والبرامج التليفزيو...             6495
#       أنشطة الأمن والتحقيقات                                        24725
#       أنشطة الاستخدام                                               50536
#       أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...              239
#
#                                                           saudis_percentage  \
# size  Economic_Activity
# صغيرة أبحاث الإعلان والسوق                                         0.410277
#       أنشطة إنتاج الأفلام والفيديو والبرامج التليفزيو...           0.501463
#       أنشطة الأمن والتحقيقات                                       0.859171
#       أنشطة الاستخدام                                              0.408184
#       أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...           0.108787
#
#                                                           nonsaudis_percentage
# size  Economic_Activity
# صغيرة أبحاث الإعلان والسوق                                            0.589723
#       أنشطة إنتاج الأفلام والفيديو والبرامج التليفزيو...              0.498537
#       أنشطة الأمن والتحقيقات                                          0.140829
#       أنشطة الاستخدام                                                 0.591816
#       أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...              0.891213

# %%
size_based_on_region = df.groupby(['region','size'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum()

# %%
size_based_on_region['saudis_percentage'] = (size_based_on_region['Number_Of_Saudis'] / size_based_on_region['total_employees'])
size_based_on_region['nonsaudis_percentage'] = (size_based_on_region['Number_Of_Nonsaudis'] / size_based_on_region['total_employees'])

# %%
size_based_on_region.head()
# Out:
#                                Number_Of_Establishments  Number_Of_Saudis  \
# region          size
# المنطقة الشرقية صغيرة                            305223           1074845
#                 كبيرة                              9992           3330916
#                 متناهية الصغر                   1132140            376282
#                 متوسطة                            41201           1161015
# منطقة الباحة    صغيرة                             12904             36018
#
#                                Number_Of_Male_Saudis  Number_Of_Female_Saudis  \
# region          size
# المنطقة الشرقية صغيرة                         542234                   532611
#                 كبيرة                        2735116                   595800
#                 متناهية الصغر                 189364                   186918
#                 متوسطة                        706746                   454269
# منطقة الباحة    صغيرة                          21857                    14161
#
#                                Number_Of_Nonsaudis  Number_Of_Male_Nonaudis  \
# region          size
# المنطقة الشرقية صغيرة                      3349180                  3275525
#                 كبيرة                      6956702                  6625103
#                 متناهية الصغر              2413241                  2379813
#                 متوسطة                     3043967                  2975533
# منطقة الباحة    صغيرة                       114707                   111178
#
#                                Number_Of_Female_Nonaudis  total_employees  \
# region          size
# المنطقة الشرقية صغيرة                              73655          4424025
#                 كبيرة                             331599         10287618
#                 متناهية الصغر                      33428          2789523
#                 متوسطة                             68434          4204982
# منطقة الباحة    صغيرة                               3529           150725
#
#                                saudis_percentage  nonsaudis_percentage
# region          size
# المنطقة الشرقية صغيرة                   0.242956              0.757044
#                 كبيرة                   0.323779              0.676221
#                 متناهية الصغر           0.134891              0.865109
#                 متوسطة                  0.276105              0.723895
# منطقة الباحة    صغيرة                   0.238965              0.761035

# %%
region_based_on_size = df.groupby(['size', 'region'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum()

# %%
region_based_on_size['saudis_percentage'] = (region_based_on_size['Number_Of_Saudis'] / region_based_on_size['total_employees'])
region_based_on_size['nonsaudis_percentage'] = (region_based_on_size['Number_Of_Nonsaudis'] / region_based_on_size['total_employees'])

# %%
region_based_on_size.head()
# Out:
#                              Number_Of_Establishments  Number_Of_Saudis  \
# size  region
# صغيرة المنطقة الشرقية                          305223           1074845
#       منطقة الباحة                              12904             36018
#       منطقة الجوف                               17570             48652
#       منطقة الحدود الشمالية                     10457             28302
#       منطقة الرياض                             588676           2168089
#
#                              Number_Of_Male_Saudis  Number_Of_Female_Saudis  \
# size  region
# صغيرة المنطقة الشرقية                       542234                   532611
#       منطقة الباحة                           21857                    14161
#       منطقة الجوف                            28067                    20585
#       منطقة الحدود الشمالية                  14450                    13852
#       منطقة الرياض                          946464                  1221625
#
#                              Number_Of_Nonsaudis  Number_Of_Male_Nonaudis  \
# size  region
# صغيرة المنطقة الشرقية                    3349180                  3275525
#       منطقة الباحة                        114707                   111178
#       منطقة الجوف                         161435                   156880
#       منطقة الحدود الشمالية                99349                    95661
#       منطقة الرياض                       6538255                  6309727
#
#                              Number_Of_Female_Nonaudis  total_employees  \
# size  region
# صغيرة المنطقة الشرقية                            73655          4424025
#       منطقة الباحة                                3529           150725
#       منطقة الجوف                                 4555           210087
#       منطقة الحدود الشمالية                       3688           127651
#       منطقة الرياض                              228528          8706344
#
#                              saudis_percentage  nonsaudis_percentage
# size  region
# صغيرة المنطقة الشرقية                 0.242956              0.757044
#       منطقة الباحة                    0.238965              0.761035
#       منطقة الجوف                     0.231580              0.768420
#       منطقة الحدود الشمالية           0.221714              0.778286
#       منطقة الرياض                    0.249024              0.750976

# %%
activity_based_on_region = df.groupby(['region'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum()

# %%
activity_based_on_region['saudis_percentage'] = (activity_based_on_region['Number_Of_Saudis'] / activity_based_on_region['total_employees'])
activity_based_on_region['nonsaudis_percentage'] = (activity_based_on_region['Number_Of_Nonsaudis'] / activity_based_on_region['total_employees'])

# %%
activity_based_on_region.head()
# Out:
#                        Number_Of_Establishments  Number_Of_Saudis  \
# region
# المنطقة الشرقية                         1488556           5943058
# منطقة الباحة                             110232             76897
# منطقة الجوف                              185026            114683
# منطقة الحدود الشمالية                    121574             77381
# منطقة الرياض                            5564655          11163882
#
#                        Number_Of_Male_Saudis  Number_Of_Female_Saudis  \
# region
# المنطقة الشرقية                      4173460                  1769598
# منطقة الباحة                           48202                    28695
# منطقة الجوف                            68224                    46459
# منطقة الحدود الشمالية                  45623                    31758
# منطقة الرياض                         6426942                  4736940
#
#                        Number_Of_Nonsaudis  Number_Of_Male_Nonaudis  \
# region
# المنطقة الشرقية                   15763090                 15255974
# منطقة الباحة                        357668                   351001
# منطقة الجوف                         587960                   575734
# منطقة الحدود الشمالية               431872                   418817
# منطقة الرياض                      39319163                 37271760
#
#                        Number_Of_Female_Nonaudis  total_employees  \
# region
# المنطقة الشرقية                           507116         21706148
# منطقة الباحة                                6667           434565
# منطقة الجوف                                12226           702643
# منطقة الحدود الشمالية                      13055           509253
# منطقة الرياض                             2047403         50483045
#
#                        saudis_percentage  nonsaudis_percentage
# region
# المنطقة الشرقية                 0.273796              0.726204
# منطقة الباحة                    0.176952              0.823048
# منطقة الجوف                     0.163217              0.836783
# منطقة الحدود الشمالية           0.151950              0.848050
# منطقة الرياض                    0.221141              0.778859

# %%
region_based_on_activity = df.groupby(['Economic_Activity', 'region'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum()

# %%
region_based_on_activity['saudis_percentage'] = (region_based_on_activity['Number_Of_Saudis'] / region_based_on_activity['total_employees'])
region_based_on_activity['nonsaudis_percentage'] = (region_based_on_activity['Number_Of_Nonsaudis'] / region_based_on_activity['total_employees'])

# %%
region_based_on_activity.head()
# Out:
#                                             Number_Of_Establishments  \
# Economic_Activity    region
# أبحاث الإعلان والسوق المنطقة الشرقية                            9939
#                      منطقة الباحة                                306
#                      منطقة الجوف                                 800
#                      منطقة الحدود الشمالية                       321
#                      منطقة الرياض                              29557
#
#                                             Number_Of_Saudis  \
# Economic_Activity    region
# أبحاث الإعلان والسوق المنطقة الشرقية                   26985
#                      منطقة الباحة                        228
#                      منطقة الجوف                         219
#                      منطقة الحدود الشمالية               209
#                      منطقة الرياض                     148168
#
#                                             Number_Of_Male_Saudis  \
# Economic_Activity    region
# أبحاث الإعلان والسوق المنطقة الشرقية                        14510
#                      منطقة الباحة                             124
#                      منطقة الجوف                              130
#                      منطقة الحدود الشمالية                     83
#                      منطقة الرياض                           95791
#
#                                             Number_Of_Female_Saudis  \
# Economic_Activity    region
# أبحاث الإعلان والسوق المنطقة الشرقية                          12475
#                      منطقة الباحة                               104
#                      منطقة الجوف                                 89
#                      منطقة الحدود الشمالية                      126
#                      منطقة الرياض                             52377
#
#                                             Number_Of_Nonsaudis  \
# Economic_Activity    region
# أبحاث الإعلان والسوق المنطقة الشرقية                      47798
#                      منطقة الباحة                           659
#                      منطقة الجوف                           1843
#                      منطقة الحدود الشمالية                  808
#                      منطقة الرياض                        119578
#
#                                             Number_Of_Male_Nonaudis  \
# Economic_Activity    region
# أبحاث الإعلان والسوق المنطقة الشرقية                          47143
#                      منطقة الباحة                               659
#                      منطقة الجوف                               1826
#                      منطقة الحدود الشمالية                      808
#                      منطقة الرياض                            109910
#
#                                             Number_Of_Female_Nonaudis  \
# Economic_Activity    region
# أبحاث الإعلان والسوق المنطقة الشرقية                              655
#                      منطقة الباحة                                   0
#                      منطقة الجوف                                   17
#                      منطقة الحدود الشمالية                          0
#                      منطقة الرياض                                9668
#
#                                             total_employees  \
# Economic_Activity    region
# أبحاث الإعلان والسوق المنطقة الشرقية                  74783
#                      منطقة الباحة                       887
#                      منطقة الجوف                       2062
#                      منطقة الحدود الشمالية             1017
#                      منطقة الرياض                    267746
#
#                                             saudis_percentage  \
# Economic_Activity    region
# أبحاث الإعلان والسوق المنطقة الشرقية                 0.360844
#                      منطقة الباحة                    0.257046
#                      منطقة الجوف                     0.106208
#                      منطقة الحدود الشمالية           0.205506
#                      منطقة الرياض                    0.553390
#
#                                             nonsaudis_percentage
# Economic_Activity    region
# أبحاث الإعلان والسوق المنطقة الشرقية                    0.639156
#                      منطقة الباحة                       0.742954
#                      منطقة الجوف                        0.893792
#                      منطقة الحدود الشمالية              0.794494
#                      منطقة الرياض                       0.446610

# %% [markdown]
# ## Q1 Page 1

# %%
df_2022['total_employees'] = df_2022['Number_Of_Saudis'] + df_2022['Number_Of_Nonsaudis']
df_2023['total_employees'] = df_2023['Number_Of_Saudis'] + df_2023['Number_Of_Nonsaudis']
df_2024['total_employees'] = df_2024['Number_Of_Saudis'] + df_2024['Number_Of_Nonsaudis']


# quarter group for 2022
df_2022_q_group = df_2022.groupby(['Q'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum().reset_index()


# quarter group for 2023
df_2023_q_group = df_2023.groupby(['Q'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum().reset_index()


# quarter group for 2024
df_2024_q_group = df_2024.groupby(['Q'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum().reset_index()

# %%
df_2022_q_group['year'] = 2022
df_2023_q_group['year'] = 2023
df_2024_q_group['year'] = 2024

# %%
df_q_group = pd.concat([df_2022_q_group, df_2023_q_group], ignore_index=True)

# %%
df_q_group.head()
# Out:
#    Q  Number_Of_Establishments  Number_Of_Saudis  Number_Of_Male_Saudis  \
# 0  1                    894135           2373778                1533509
# 1  2                    969690           2440961                1562919
# 2  3                   1079595           2136188                1314928
# 3  4                   1145467           2193452                1332956
# 4  1                   1199843           2233716                1343134
#
#    Number_Of_Female_Saudis  Number_Of_Nonsaudis  Number_Of_Male_Nonaudis  \
# 0                   840269              6641301                  6343392
# 1                   878042              7091971                  6780466
# 2                   821260              7159790                  6881517
# 3                   860496              7441496                  7153550
# 4                   890582              7699862                  7393060
#
#    Number_Of_Female_Nonaudis  total_employees  year
# 0                     297909          9015079  2022
# 1                     311505          9532932  2022
# 2                     278273          9295978  2022
# 3                     287946          9634948  2022
# 4                     306802          9933578  2023

# %%
# export df_q_group to csv
df_q_group.to_csv('data/df_q_group.csv', index=False)

# %% [markdown]
# # Q2 Page 2

# %%
last_Q = df[df["Q"] == 4]
last_Q_2022 = last_Q[last_Q["year"] == 2022]
last_Q_2023 = last_Q[last_Q["year"] == 2023]
last_Q_2024 = df[(df["year"] == 2024) & (df["Q"] == 3)]

activity_group22 = last_Q_2022.groupby(['Economic_Activity'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum().sort_values(by="total_employees", ascending=False)
activity_group23 = last_Q_2023.groupby(['Economic_Activity'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum().sort_values(by="total_employees", ascending=False)
activity_group24 = last_Q_2024.groupby(['Economic_Activity'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum().sort_values(by="total_employees", ascending=False)

# %%
activity_group24.head(1)
# Out:
#                    Number_Of_Establishments  Number_Of_Saudis  \
# Economic_Activity
# تشييد المباني                        167216            225616
#
#                    Number_Of_Male_Saudis  Number_Of_Female_Saudis  \
# Economic_Activity
# تشييد المباني                     128292                    97324
#
#                    Number_Of_Nonsaudis  Number_Of_Male_Nonaudis  \
# Economic_Activity
# تشييد المباني                  1618963                  1597509
#
#                    Number_Of_Female_Nonaudis  total_employees
# Economic_Activity
# تشييد المباني                          21454          1844579

# %%
last_Q = df.copy()
last_Q_2022 = last_Q[last_Q["year"] == 2022]
last_Q_2023 = last_Q[last_Q["year"] == 2023]
last_Q_2024 = last_Q[last_Q["year"] == 2024]

activity_group22 = last_Q_2022.groupby(['Economic_Activity'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum().sort_values(by="total_employees", ascending=False)
activity_group23 = last_Q_2023.groupby(['Economic_Activity', 'Q'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum().sort_values(by="total_employees", ascending=False)
activity_group24 = last_Q_2024.groupby(['Economic_Activity', 'Q'])[['Number_Of_Establishments', 'Number_Of_Saudis', 'Number_Of_Male_Saudis', 'Number_Of_Female_Saudis', 'Number_Of_Nonsaudis', 'Number_Of_Male_Nonaudis', 'Number_Of_Female_Nonaudis', 'total_employees']].sum().sort_values(by="total_employees", ascending=False)

# %%
activity_group22
# Out:
#                                                     Number_Of_Establishments  \
# Economic_Activity
# تشييد المباني                                                         497274
# تجارة التجزئة، باستثناء المركبات ذات المحركات و...                    586795
# أنشطة التشييد المتخصصة                                                212488
# أنشطة خدمات الأطعمة والمشروبات                                        334891
# أنشطة تقديم الخدمات للمباني وتجميل المواقع                             64943
# تجارة الجملة ، باستثناء المركبات ذات المحركات و...                    265069
# الهندسة المدنية                                                        22600
# الصحة البشرية                                                          21806
# أنشطة الاستخدام                                                         9379
# النقل البري و النقل عبر الأنابيب                                      125895
# تجارة الجملة والتجزئة ، وإصلاح المركبات ذات الم...                    233779
# الأنشطة الإيجارية                                                     275468
# غير معرف                                                              341912
# صنع منتجات المعادن اللافلزية الأخرى                                    26945
# التعليم                                                                37004
# صُنع المنتجات الغذائية                                                 34670
# أنشطة الخدمات الشخصية الأخرى                                          166499
# الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإل...                      5603
# صيد الأسماك وتربية المائيات                                           190023
# صنع منتجات المعادن المشكلة ( باستثناء الآلات وا...                     54379
# أنشطة زراعة المحاصيل والإنتاج الحيواني والصيد و...                     81865
# التخزين وأنشطة الدعم للنقل                                             24321
# إصلاح أجهزة الحاسوب والسلع الشخصية والمنزلية                           32452
# أنشطة المعمارية والهندسية ، والاختبارات الفنية ...                     28737
# صُنع المواد الكيميائية والمنتجات الكيميائية                             8936
# استخراج النفط الخام والغاز الطبيعي                                       432
# الإقامة                                                                21661
# أنشطة جمع النفايات ومعالجتها وتصريفها ، واسترجا...                      1854
# الأنشطة العقارية                                                       29658
# إصلاح وتركيب الآلات والمعدات                                           20158
# صُنع الملبوسات                                                         62005
# أنشطة البرمجة الحاسوبية والخبرة الاستشارية وما ...                     13921
# الأنشطة الإدارية للمكاتب ، وأنشطة الدعم للمكاتب...                     26542
# أبحاث الإعلان والسوق                                                   23893
# صنع الأثاث                                                             22658
# أنشطة خدمات دعم التعدين                                                 1331
# صنع الفلزات القاعدية                                                    6767
# أنشطة الخدمات المالية ، فيما عدا تمويل التأمين ...                      6661
# توصيل الكهرباء والغاز والبخار وتكييف الهواء                             2061
# الأنشطة المساعدة لأنشطة الخدمات المالية وأنشطة ...                      2549
# صنع منتجات المطاط واللدائن                                              3530
# أنشطة الأمن والتحقيقات                                                  1945
# الاتصالات                                                               4754
# أنشطة العمل الاجتماعي، دون إقامة                                       11090
# أنشطة المكاتب الرئيسية، والأنشطة الاستشارية في ...                      5829
# الصناعة التحويلية الأخرى                                                4415
# صُنع المشروبات                                                          2360
# الأنشطة الرياضية وأنشطة التسلية والترفيه                               11874
# صُنع الخشب ومنتجات الخشب والفلين ، باستثناء الأ...                     15743
# صنع المعدات الكهربائية                                                  3936
# الأنشطة القانونية وأنشطة المحاسبة                                      14676
# أنشطة خدمات المعلومات                                                   3232
# الأنشطة الأخرى للتعدين واستغلال المحاجر                                 4271
# صناعة الآلات والمعدات غير المصنفة في موضع أخر                           3416
# صُنع الورق ومنتجات الورق                                                2579
# وكالات السفر ومشغّلو الجولات السياحية وخدمات ال...                      7711
# أنشطة المنظمات ذات العضوية                                             12050
# صُنع المنسوجات                                                          7763
# صنع فحم الكوك والمنتجات النفطية المكررة                                  781
# النقل الجوي                                                             2213
# تجميع المياه ومعالجتها وتوصيلها                                         5301
# الطباعة واستنساخ وسائط الأعلام المسجّلة                                 4468
# أنشطة البريد ونقل الرسائل والطرود بواسطة مندوبين                        2236
# الصرف الصحي                                                             1659
# الأنشطة المهنية والعلمية والتقنية الأخرى                                7128
# صناعة المركبات ذات المحركات والمركبات المقطورة ...                      1322
# تمويل التأمين وإعادة التأمين وصناديق المعاشات ا...                       343
# أنشطة المعالجة وخدمات إدارة النفايات الأخرى                               79
# صنع المنتجات الصيدلانية الأساسية والمستحضرات ال...                      1220
# صناعة معدات النقل الأخرى                                                 769
# أنشطة النشر                                                             2133
# النقل المائي                                                            1845
# صُنع المنتجات الجلدية والمنتجات ذات الصلة                               1136
# صنع الحواسيب والمنتجات الإلكترونية والبصرية                             2096
# الرعاية مع الإقامة                                                       565
# البحث والتطوير في المجال العلمي                                          887
# تعدين ركازات الفلزات                                                    1149
# الأنشطة الإبداعية والفنون وأنشطة الترفيه                                1188
# الأنشطة البيطرية                                                        1336
# أنشطة المكتبات والمحفوظات والمتاحف والأنشطة الث...                      1037
# أنشطة البرمجة والإذاعة                                                   559
# تعدين الفحم والليغنيت                                                    143
# أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                       145
# الحراجة وقطع الأخشاب                                                      58
# الأنشطة غير المتميزة لإنتاج السلع والخدمات التي...                        33
#
#                                                     Number_Of_Saudis  \
# Economic_Activity
# تشييد المباني                                                 672849
# تجارة التجزئة، باستثناء المركبات ذات المحركات و...            931076
# أنشطة التشييد المتخصصة                                        420256
# أنشطة خدمات الأطعمة والمشروبات                                476301
# أنشطة تقديم الخدمات للمباني وتجميل المواقع                    400704
# تجارة الجملة ، باستثناء المركبات ذات المحركات و...            576196
# الهندسة المدنية                                               329808
# الصحة البشرية                                                 508340
# أنشطة الاستخدام                                                62329
# النقل البري و النقل عبر الأنابيب                              234466
# تجارة الجملة والتجزئة ، وإصلاح المركبات ذات الم...            188687
# الأنشطة الإيجارية                                              64985
# غير معرف                                                       43670
# صنع منتجات المعادن اللافلزية الأخرى                           129641
# التعليم                                                       346481
# صُنع المنتجات الغذائية                                        128543
# أنشطة الخدمات الشخصية الأخرى                                   72981
# الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإل...            405887
# صيد الأسماك وتربية المائيات                                    25048
# صنع منتجات المعادن المشكلة ( باستثناء الآلات وا...            109829
# أنشطة زراعة المحاصيل والإنتاج الحيواني والصيد و...             59229
# التخزين وأنشطة الدعم للنقل                                    154769
# إصلاح أجهزة الحاسوب والسلع الشخصية والمنزلية                   13783
# أنشطة المعمارية والهندسية ، والاختبارات الفنية ...            121971
# صُنع المواد الكيميائية والمنتجات الكيميائية                   128417
# استخراج النفط الخام والغاز الطبيعي                            266301
# الإقامة                                                        95088
# أنشطة جمع النفايات ومعالجتها وتصريفها ، واسترجا...             42002
# الأنشطة العقارية                                               92311
# إصلاح وتركيب الآلات والمعدات                                   67899
# صُنع الملبوسات                                                 28860
# أنشطة البرمجة الحاسوبية والخبرة الاستشارية وما ...            115141
# الأنشطة الإدارية للمكاتب ، وأنشطة الدعم للمكاتب...             81067
# أبحاث الإعلان والسوق                                           78861
# صنع الأثاث                                                     28111
# أنشطة خدمات دعم التعدين                                       114381
# صنع الفلزات القاعدية                                           44501
# أنشطة الخدمات المالية ، فيما عدا تمويل التأمين ...            124683
# توصيل الكهرباء والغاز والبخار وتكييف الهواء                   133290
# الأنشطة المساعدة لأنشطة الخدمات المالية وأنشطة ...            140060
# صنع منتجات المطاط واللدائن                                     35683
# أنشطة الأمن والتحقيقات                                        134164
# الاتصالات                                                      98837
# أنشطة العمل الاجتماعي، دون إقامة                               89488
# أنشطة المكاتب الرئيسية، والأنشطة الاستشارية في ...             64032
# الصناعة التحويلية الأخرى                                       27246
# صُنع المشروبات                                                 29296
# الأنشطة الرياضية وأنشطة التسلية والترفيه                       37971
# صُنع الخشب ومنتجات الخشب والفلين ، باستثناء الأ...             16119
# صنع المعدات الكهربائية                                         27081
# الأنشطة القانونية وأنشطة المحاسبة                              49482
# أنشطة خدمات المعلومات                                          54536
# الأنشطة الأخرى للتعدين واستغلال المحاجر                        25067
# صناعة الآلات والمعدات غير المصنفة في موضع أخر                  25143
# صُنع الورق ومنتجات الورق                                       20215
# وكالات السفر ومشغّلو الجولات السياحية وخدمات ال...             35490
# أنشطة المنظمات ذات العضوية                                     43086
# صُنع المنسوجات                                                 14922
# صنع فحم الكوك والمنتجات النفطية المكررة                        39251
# النقل الجوي                                                    36406
# تجميع المياه ومعالجتها وتوصيلها                                19207
# الطباعة واستنساخ وسائط الأعلام المسجّلة                        17914
# أنشطة البريد ونقل الرسائل والطرود بواسطة مندوبين               10800
# الصرف الصحي                                                     5745
# الأنشطة المهنية والعلمية والتقنية الأخرى                       14675
# صناعة المركبات ذات المحركات والمركبات المقطورة ...              7901
# تمويل التأمين وإعادة التأمين وصناديق المعاشات ا...             24564
# أنشطة المعالجة وخدمات إدارة النفايات الأخرى                     5993
# صنع المنتجات الصيدلانية الأساسية والمستحضرات ال...             11029
# صناعة معدات النقل الأخرى                                       16266
# أنشطة النشر                                                    10354
# النقل المائي                                                    7618
# صُنع المنتجات الجلدية والمنتجات ذات الصلة                       1921
# صنع الحواسيب والمنتجات الإلكترونية والبصرية                     2689
# الرعاية مع الإقامة                                              7793
# البحث والتطوير في المجال العلمي                                 6507
# تعدين ركازات الفلزات                                            3508
# الأنشطة الإبداعية والفنون وأنشطة الترفيه                        2617
# الأنشطة البيطرية                                                2444
# أنشطة المكتبات والمحفوظات والمتاحف والأنشطة الث...               929
# أنشطة البرمجة والإذاعة                                          1437
# تعدين الفحم والليغنيت                                            103
# أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                22
# الحراجة وقطع الأخشاب                                              23
# الأنشطة غير المتميزة لإنتاج السلع والخدمات التي...                 3
#
#                                                     Number_Of_Male_Saudis  \
# Economic_Activity
# تشييد المباني                                                      391680
# تجارة التجزئة، باستثناء المركبات ذات المحركات و...                 479719
# أنشطة التشييد المتخصصة                                             273750
# أنشطة خدمات الأطعمة والمشروبات                                     253062
# أنشطة تقديم الخدمات للمباني وتجميل المواقع                         242363
# تجارة الجملة ، باستثناء المركبات ذات المحركات و...                 328890
# الهندسة المدنية                                                    241217
# الصحة البشرية                                                      228868
# أنشطة الاستخدام                                                     24332
# النقل البري و النقل عبر الأنابيب                                   161952
# تجارة الجملة والتجزئة ، وإصلاح المركبات ذات الم...                 124726
# الأنشطة الإيجارية                                                   43294
# غير معرف                                                            24425
# صنع منتجات المعادن اللافلزية الأخرى                                 87811
# التعليم                                                            133260
# صُنع المنتجات الغذائية                                              72135
# أنشطة الخدمات الشخصية الأخرى                                        25690
# الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإل...                 320120
# صيد الأسماك وتربية المائيات                                         13114
# صنع منتجات المعادن المشكلة ( باستثناء الآلات وا...                  75824
# أنشطة زراعة المحاصيل والإنتاج الحيواني والصيد و...                  44803
# التخزين وأنشطة الدعم للنقل                                         115597
# إصلاح أجهزة الحاسوب والسلع الشخصية والمنزلية                         8525
# أنشطة المعمارية والهندسية ، والاختبارات الفنية ...                  83254
# صُنع المواد الكيميائية والمنتجات الكيميائية                        105102
# استخراج النفط الخام والغاز الطبيعي                                 251923
# الإقامة                                                             59218
# أنشطة جمع النفايات ومعالجتها وتصريفها ، واسترجا...                  23806
# الأنشطة العقارية                                                    58115
# إصلاح وتركيب الآلات والمعدات                                        53665
# صُنع الملبوسات                                                       9959
# أنشطة البرمجة الحاسوبية والخبرة الاستشارية وما ...                  69086
# الأنشطة الإدارية للمكاتب ، وأنشطة الدعم للمكاتب...                  44541
# أبحاث الإعلان والسوق                                                46905
# صنع الأثاث                                                          13783
# أنشطة خدمات دعم التعدين                                            108219
# صنع الفلزات القاعدية                                                33206
# أنشطة الخدمات المالية ، فيما عدا تمويل التأمين ...                  95247
# توصيل الكهرباء والغاز والبخار وتكييف الهواء                        130196
# الأنشطة المساعدة لأنشطة الخدمات المالية وأنشطة ...                 106999
# صنع منتجات المطاط واللدائن                                          21998
# أنشطة الأمن والتحقيقات                                             121192
# الاتصالات                                                           75204
# أنشطة العمل الاجتماعي، دون إقامة                                    36946
# أنشطة المكاتب الرئيسية، والأنشطة الاستشارية في ...                  37405
# الصناعة التحويلية الأخرى                                            17521
# صُنع المشروبات                                                      18161
# الأنشطة الرياضية وأنشطة التسلية والترفيه                            16901
# صُنع الخشب ومنتجات الخشب والفلين ، باستثناء الأ...                   8259
# صنع المعدات الكهربائية                                              20964
# الأنشطة القانونية وأنشطة المحاسبة                                   30282
# أنشطة خدمات المعلومات                                               31753
# الأنشطة الأخرى للتعدين واستغلال المحاجر                             17824
# صناعة الآلات والمعدات غير المصنفة في موضع أخر                       20266
# صُنع الورق ومنتجات الورق                                            12344
# وكالات السفر ومشغّلو الجولات السياحية وخدمات ال...                  24524
# أنشطة المنظمات ذات العضوية                                          26799
# صُنع المنسوجات                                                       9549
# صنع فحم الكوك والمنتجات النفطية المكررة                             37513
# النقل الجوي                                                         32206
# تجميع المياه ومعالجتها وتوصيلها                                     16201
# الطباعة واستنساخ وسائط الأعلام المسجّلة                             10255
# أنشطة البريد ونقل الرسائل والطرود بواسطة مندوبين                     6048
# الصرف الصحي                                                          4084
# الأنشطة المهنية والعلمية والتقنية الأخرى                             8056
# صناعة المركبات ذات المحركات والمركبات المقطورة ...                   5485
# تمويل التأمين وإعادة التأمين وصناديق المعاشات ا...                  15702
# أنشطة المعالجة وخدمات إدارة النفايات الأخرى                          4564
# صنع المنتجات الصيدلانية الأساسية والمستحضرات ال...                   6317
# صناعة معدات النقل الأخرى                                            15402
# أنشطة النشر                                                          4801
# النقل المائي                                                         5530
# صُنع المنتجات الجلدية والمنتجات ذات الصلة                             805
# صنع الحواسيب والمنتجات الإلكترونية والبصرية                          1853
# الرعاية مع الإقامة                                                   1208
# البحث والتطوير في المجال العلمي                                      4840
# تعدين ركازات الفلزات                                                 3038
# الأنشطة الإبداعية والفنون وأنشطة الترفيه                             1479
# الأنشطة البيطرية                                                     1196
# أنشطة المكتبات والمحفوظات والمتاحف والأنشطة الث...                    565
# أنشطة البرمجة والإذاعة                                                798
# تعدين الفحم والليغنيت                                                  69
# أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                     15
# الحراجة وقطع الأخشاب                                                    9
# الأنشطة غير المتميزة لإنتاج السلع والخدمات التي...                      0
#
#                                                     Number_Of_Female_Saudis  \
# Economic_Activity
# تشييد المباني                                                        281169
# تجارة التجزئة، باستثناء المركبات ذات المحركات و...                   451357
# أنشطة التشييد المتخصصة                                               146506
# أنشطة خدمات الأطعمة والمشروبات                                       223239
# أنشطة تقديم الخدمات للمباني وتجميل المواقع                           158341
# تجارة الجملة ، باستثناء المركبات ذات المحركات و...                   247306
# الهندسة المدنية                                                       88591
# الصحة البشرية                                                        279472
# أنشطة الاستخدام                                                       37997
# النقل البري و النقل عبر الأنابيب                                      72514
# تجارة الجملة والتجزئة ، وإصلاح المركبات ذات الم...                    63961
# الأنشطة الإيجارية                                                     21691
# غير معرف                                                              19245
# صنع منتجات المعادن اللافلزية الأخرى                                   41830
# التعليم                                                              213221
# صُنع المنتجات الغذائية                                                56408
# أنشطة الخدمات الشخصية الأخرى                                          47291
# الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإل...                    85767
# صيد الأسماك وتربية المائيات                                           11934
# صنع منتجات المعادن المشكلة ( باستثناء الآلات وا...                    34005
# أنشطة زراعة المحاصيل والإنتاج الحيواني والصيد و...                    14426
# التخزين وأنشطة الدعم للنقل                                            39172
# إصلاح أجهزة الحاسوب والسلع الشخصية والمنزلية                           5258
# أنشطة المعمارية والهندسية ، والاختبارات الفنية ...                    38717
# صُنع المواد الكيميائية والمنتجات الكيميائية                           23315
# استخراج النفط الخام والغاز الطبيعي                                    14378
# الإقامة                                                               35870
# أنشطة جمع النفايات ومعالجتها وتصريفها ، واسترجا...                    18196
# الأنشطة العقارية                                                      34196
# إصلاح وتركيب الآلات والمعدات                                          14234
# صُنع الملبوسات                                                        18901
# أنشطة البرمجة الحاسوبية والخبرة الاستشارية وما ...                    46055
# الأنشطة الإدارية للمكاتب ، وأنشطة الدعم للمكاتب...                    36526
# أبحاث الإعلان والسوق                                                  31956
# صنع الأثاث                                                            14328
# أنشطة خدمات دعم التعدين                                                6162
# صنع الفلزات القاعدية                                                  11295
# أنشطة الخدمات المالية ، فيما عدا تمويل التأمين ...                    29436
# توصيل الكهرباء والغاز والبخار وتكييف الهواء                            3094
# الأنشطة المساعدة لأنشطة الخدمات المالية وأنشطة ...                    33061
# صنع منتجات المطاط واللدائن                                            13685
# أنشطة الأمن والتحقيقات                                                12972
# الاتصالات                                                             23633
# أنشطة العمل الاجتماعي، دون إقامة                                      52542
# أنشطة المكاتب الرئيسية، والأنشطة الاستشارية في ...                    26627
# الصناعة التحويلية الأخرى                                               9725
# صُنع المشروبات                                                        11135
# الأنشطة الرياضية وأنشطة التسلية والترفيه                              21070
# صُنع الخشب ومنتجات الخشب والفلين ، باستثناء الأ...                     7860
# صنع المعدات الكهربائية                                                 6117
# الأنشطة القانونية وأنشطة المحاسبة                                     19200
# أنشطة خدمات المعلومات                                                 22783
# الأنشطة الأخرى للتعدين واستغلال المحاجر                                7243
# صناعة الآلات والمعدات غير المصنفة في موضع أخر                          4877
# صُنع الورق ومنتجات الورق                                               7871
# وكالات السفر ومشغّلو الجولات السياحية وخدمات ال...                    10966
# أنشطة المنظمات ذات العضوية                                            16287
# صُنع المنسوجات                                                         5373
# صنع فحم الكوك والمنتجات النفطية المكررة                                1738
# النقل الجوي                                                            4200
# تجميع المياه ومعالجتها وتوصيلها                                        3006
# الطباعة واستنساخ وسائط الأعلام المسجّلة                                7659
# أنشطة البريد ونقل الرسائل والطرود بواسطة مندوبين                       4752
# الصرف الصحي                                                            1661
# الأنشطة المهنية والعلمية والتقنية الأخرى                               6619
# صناعة المركبات ذات المحركات والمركبات المقطورة ...                     2416
# تمويل التأمين وإعادة التأمين وصناديق المعاشات ا...                     8862
# أنشطة المعالجة وخدمات إدارة النفايات الأخرى                            1429
# صنع المنتجات الصيدلانية الأساسية والمستحضرات ال...                     4712
# صناعة معدات النقل الأخرى                                                864
# أنشطة النشر                                                            5553
# النقل المائي                                                           2088
# صُنع المنتجات الجلدية والمنتجات ذات الصلة                              1116
# صنع الحواسيب والمنتجات الإلكترونية والبصرية                             836
# الرعاية مع الإقامة                                                     6585
# البحث والتطوير في المجال العلمي                                        1667
# تعدين ركازات الفلزات                                                    470
# الأنشطة الإبداعية والفنون وأنشطة الترفيه                               1138
# الأنشطة البيطرية                                                       1248
# أنشطة المكتبات والمحفوظات والمتاحف والأنشطة الث...                      364
# أنشطة البرمجة والإذاعة                                                  639
# تعدين الفحم والليغنيت                                                    34
# أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                        7
# الحراجة وقطع الأخشاب                                                     14
# الأنشطة غير المتميزة لإنتاج السلع والخدمات التي...                        3
#
#                                                     Number_Of_Nonsaudis  \
# Economic_Activity
# تشييد المباني                                                   4772175
# تجارة التجزئة، باستثناء المركبات ذات المحركات و...              2609517
# أنشطة التشييد المتخصصة                                          2042148
# أنشطة خدمات الأطعمة والمشروبات                                  1875823
# أنشطة تقديم الخدمات للمباني وتجميل المواقع                      1771719
# تجارة الجملة ، باستثناء المركبات ذات المحركات و...              1475646
# الهندسة المدنية                                                 1501432
# الصحة البشرية                                                    736425
# أنشطة الاستخدام                                                 1071757
# النقل البري و النقل عبر الأنابيب                                 891519
# تجارة الجملة والتجزئة ، وإصلاح المركبات ذات الم...               913494
# الأنشطة الإيجارية                                                790969
# غير معرف                                                         724983
# صنع منتجات المعادن اللافلزية الأخرى                              524898
# التعليم                                                          281405
# صُنع المنتجات الغذائية                                           450199
# أنشطة الخدمات الشخصية الأخرى                                     470217
# الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإل...               131650
# صيد الأسماك وتربية المائيات                                      511426
# صنع منتجات المعادن المشكلة ( باستثناء الآلات وا...               383738
# أنشطة زراعة المحاصيل والإنتاج الحيواني والصيد و...               379712
# التخزين وأنشطة الدعم للنقل                                       275235
# إصلاح أجهزة الحاسوب والسلع الشخصية والمنزلية                     324693
# أنشطة المعمارية والهندسية ، والاختبارات الفنية ...               213474
# صُنع المواد الكيميائية والمنتجات الكيميائية                      185490
# استخراج النفط الخام والغاز الطبيعي                                33789
# الإقامة                                                          174380
# أنشطة جمع النفايات ومعالجتها وتصريفها ، واسترجا...               209690
# الأنشطة العقارية                                                 147810
# إصلاح وتركيب الآلات والمعدات                                     171499
# صُنع الملبوسات                                                   192735
# أنشطة البرمجة الحاسوبية والخبرة الاستشارية وما ...                98472
# الأنشطة الإدارية للمكاتب ، وأنشطة الدعم للمكاتب...               115091
# أبحاث الإعلان والسوق                                             104183
# صنع الأثاث                                                       150628
# أنشطة خدمات دعم التعدين                                           55610
# صنع الفلزات القاعدية                                             125139
# أنشطة الخدمات المالية ، فيما عدا تمويل التأمين ...                40492
# توصيل الكهرباء والغاز والبخار وتكييف الهواء                       25297
# الأنشطة المساعدة لأنشطة الخدمات المالية وأنشطة ...                17957
# صنع منتجات المطاط واللدائن                                       111106
# أنشطة الأمن والتحقيقات                                             5847
# الاتصالات                                                         34838
# أنشطة العمل الاجتماعي، دون إقامة                                  41559
# أنشطة المكاتب الرئيسية، والأنشطة الاستشارية في ...                44216
# الصناعة التحويلية الأخرى                                          80756
# صُنع المشروبات                                                    77797
# الأنشطة الرياضية وأنشطة التسلية والترفيه                          63726
# صُنع الخشب ومنتجات الخشب والفلين ، باستثناء الأ...                80578
# صنع المعدات الكهربائية                                            68095
# الأنشطة القانونية وأنشطة المحاسبة                                 42760
# أنشطة خدمات المعلومات                                             32315
# الأنشطة الأخرى للتعدين واستغلال المحاجر                           60814
# صناعة الآلات والمعدات غير المصنفة في موضع أخر                     57868
# صُنع الورق ومنتجات الورق                                          59472
# وكالات السفر ومشغّلو الجولات السياحية وخدمات ال...                43821
# أنشطة المنظمات ذات العضوية                                        33030
# صُنع المنسوجات                                                    56003
# صنع فحم الكوك والمنتجات النفطية المكررة                           25705
# النقل الجوي                                                       17146
# تجميع المياه ومعالجتها وتوصيلها                                   31245
# الطباعة واستنساخ وسائط الأعلام المسجّلة                           31108
# أنشطة البريد ونقل الرسائل والطرود بواسطة مندوبين                  32384
# الصرف الصحي                                                       36466
# الأنشطة المهنية والعلمية والتقنية الأخرى                          24647
# صناعة المركبات ذات المحركات والمركبات المقطورة ...                26671
# تمويل التأمين وإعادة التأمين وصناديق المعاشات ا...                 7840
# أنشطة المعالجة وخدمات إدارة النفايات الأخرى                       26410
# صنع المنتجات الصيدلانية الأساسية والمستحضرات ال...                20959
# صناعة معدات النقل الأخرى                                          11401
# أنشطة النشر                                                       16839
# النقل المائي                                                       8870
# صُنع المنتجات الجلدية والمنتجات ذات الصلة                         10288
# صنع الحواسيب والمنتجات الإلكترونية والبصرية                        9517
# الرعاية مع الإقامة                                                 3217
# البحث والتطوير في المجال العلمي                                    4261
# تعدين ركازات الفلزات                                               4765
# الأنشطة الإبداعية والفنون وأنشطة الترفيه                           5594
# الأنشطة البيطرية                                                   5673
# أنشطة المكتبات والمحفوظات والمتاحف والأنشطة الث...                 3009
# أنشطة البرمجة والإذاعة                                             2396
# تعدين الفحم والليغنيت                                               528
# أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                  274
# الحراجة وقطع الأخشاب                                                129
# الأنشطة غير المتميزة لإنتاج السلع والخدمات التي...                   99
#
#                                                     Number_Of_Male_Nonaudis  \
# Economic_Activity
# تشييد المباني                                                       4740184
# تجارة التجزئة، باستثناء المركبات ذات المحركات و...                  2575656
# أنشطة التشييد المتخصصة                                              2026219
# أنشطة خدمات الأطعمة والمشروبات                                      1859945
# أنشطة تقديم الخدمات للمباني وتجميل المواقع                          1702847
# تجارة الجملة ، باستثناء المركبات ذات المحركات و...                  1458766
# الهندسة المدنية                                                     1496638
# الصحة البشرية                                                        400105
# أنشطة الاستخدام                                                      682803
# النقل البري و النقل عبر الأنابيب                                     889026
# تجارة الجملة والتجزئة ، وإصلاح المركبات ذات الم...                   910847
# الأنشطة الإيجارية                                                    787288
# غير معرف                                                             716209
# صنع منتجات المعادن اللافلزية الأخرى                                  523789
# التعليم                                                              236440
# صُنع المنتجات الغذائية                                               446525
# أنشطة الخدمات الشخصية الأخرى                                         400372
# الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإل...                   110374
# صيد الأسماك وتربية المائيات                                          508012
# صنع منتجات المعادن المشكلة ( باستثناء الآلات وا...                   382815
# أنشطة زراعة المحاصيل والإنتاج الحيواني والصيد و...                   378487
# التخزين وأنشطة الدعم للنقل                                           273380
# إصلاح أجهزة الحاسوب والسلع الشخصية والمنزلية                         323609
# أنشطة المعمارية والهندسية ، والاختبارات الفنية ...                   211282
# صُنع المواد الكيميائية والمنتجات الكيميائية                          184799
# استخراج النفط الخام والغاز الطبيعي                                    31318
# الإقامة                                                              171197
# أنشطة جمع النفايات ومعالجتها وتصريفها ، واسترجا...                   196456
# الأنشطة العقارية                                                     143253
# إصلاح وتركيب الآلات والمعدات                                         170672
# صُنع الملبوسات                                                       176963
# أنشطة البرمجة الحاسوبية والخبرة الاستشارية وما ...                    94983
# الأنشطة الإدارية للمكاتب ، وأنشطة الدعم للمكاتب...                   110005
# أبحاث الإعلان والسوق                                                  99533
# صنع الأثاث                                                           150123
# أنشطة خدمات دعم التعدين                                               55466
# صنع الفلزات القاعدية                                                 124850
# أنشطة الخدمات المالية ، فيما عدا تمويل التأمين ...                    39272
# توصيل الكهرباء والغاز والبخار وتكييف الهواء                           25243
# الأنشطة المساعدة لأنشطة الخدمات المالية وأنشطة ...                    17268
# صنع منتجات المطاط واللدائن                                           110793
# أنشطة الأمن والتحقيقات                                                 5725
# الاتصالات                                                             33993
# أنشطة العمل الاجتماعي، دون إقامة                                      35380
# أنشطة المكاتب الرئيسية، والأنشطة الاستشارية في ...                    41832
# الصناعة التحويلية الأخرى                                              79778
# صُنع المشروبات                                                        77649
# الأنشطة الرياضية وأنشطة التسلية والترفيه                              56507
# صُنع الخشب ومنتجات الخشب والفلين ، باستثناء الأ...                    80026
# صنع المعدات الكهربائية                                                67938
# الأنشطة القانونية وأنشطة المحاسبة                                     41290
# أنشطة خدمات المعلومات                                                 31193
# الأنشطة الأخرى للتعدين واستغلال المحاجر                               60711
# صناعة الآلات والمعدات غير المصنفة في موضع أخر                         57759
# صُنع الورق ومنتجات الورق                                              59249
# وكالات السفر ومشغّلو الجولات السياحية وخدمات ال...                    43202
# أنشطة المنظمات ذات العضوية                                            30383
# صُنع المنسوجات                                                        55499
# صنع فحم الكوك والمنتجات النفطية المكررة                               25602
# النقل الجوي                                                           14724
# تجميع المياه ومعالجتها وتوصيلها                                       31191
# الطباعة واستنساخ وسائط الأعلام المسجّلة                               30856
# أنشطة البريد ونقل الرسائل والطرود بواسطة مندوبين                      32043
# الصرف الصحي                                                           36396
# الأنشطة المهنية والعلمية والتقنية الأخرى                              22295
# صناعة المركبات ذات المحركات والمركبات المقطورة ...                    26610
# تمويل التأمين وإعادة التأمين وصناديق المعاشات ا...                     7302
# أنشطة المعالجة وخدمات إدارة النفايات الأخرى                           25716
# صنع المنتجات الصيدلانية الأساسية والمستحضرات ال...                    20437
# صناعة معدات النقل الأخرى                                              11377
# أنشطة النشر                                                           16343
# النقل المائي                                                           8712
# صُنع المنتجات الجلدية والمنتجات ذات الصلة                             10265
# صنع الحواسيب والمنتجات الإلكترونية والبصرية                            9436
# الرعاية مع الإقامة                                                     1958
# البحث والتطوير في المجال العلمي                                        4048
# تعدين ركازات الفلزات                                                   4746
# الأنشطة الإبداعية والفنون وأنشطة الترفيه                               5375
# الأنشطة البيطرية                                                       5274
# أنشطة المكتبات والمحفوظات والمتاحف والأنشطة الث...                     2972
# أنشطة البرمجة والإذاعة                                                 2308
# تعدين الفحم والليغنيت                                                   527
# أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                      264
# الحراجة وقطع الأخشاب                                                    129
# الأنشطة غير المتميزة لإنتاج السلع والخدمات التي...                       93
#
#                                                     Number_Of_Female_Nonaudis  \
# Economic_Activity
# تشييد المباني                                                           31991
# تجارة التجزئة، باستثناء المركبات ذات المحركات و...                      33861
# أنشطة التشييد المتخصصة                                                  15929
# أنشطة خدمات الأطعمة والمشروبات                                          15878
# أنشطة تقديم الخدمات للمباني وتجميل المواقع                              68872
# تجارة الجملة ، باستثناء المركبات ذات المحركات و...                      16880
# الهندسة المدنية                                                          4794
# الصحة البشرية                                                          336320
# أنشطة الاستخدام                                                        388954
# النقل البري و النقل عبر الأنابيب                                         2493
# تجارة الجملة والتجزئة ، وإصلاح المركبات ذات الم...                       2647
# الأنشطة الإيجارية                                                        3681
# غير معرف                                                                 8774
# صنع منتجات المعادن اللافلزية الأخرى                                      1109
# التعليم                                                                 44965
# صُنع المنتجات الغذائية                                                   3674
# أنشطة الخدمات الشخصية الأخرى                                            69845
# الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإل...                      21276
# صيد الأسماك وتربية المائيات                                              3414
# صنع منتجات المعادن المشكلة ( باستثناء الآلات وا...                        923
# أنشطة زراعة المحاصيل والإنتاج الحيواني والصيد و...                       1225
# التخزين وأنشطة الدعم للنقل                                               1855
# إصلاح أجهزة الحاسوب والسلع الشخصية والمنزلية                             1084
# أنشطة المعمارية والهندسية ، والاختبارات الفنية ...                       2192
# صُنع المواد الكيميائية والمنتجات الكيميائية                               691
# استخراج النفط الخام والغاز الطبيعي                                       2471
# الإقامة                                                                  3183
# أنشطة جمع النفايات ومعالجتها وتصريفها ، واسترجا...                      13234
# الأنشطة العقارية                                                         4557
# إصلاح وتركيب الآلات والمعدات                                              827
# صُنع الملبوسات                                                          15772
# أنشطة البرمجة الحاسوبية والخبرة الاستشارية وما ...                       3489
# الأنشطة الإدارية للمكاتب ، وأنشطة الدعم للمكاتب...                       5086
# أبحاث الإعلان والسوق                                                     4650
# صنع الأثاث                                                                505
# أنشطة خدمات دعم التعدين                                                   144
# صنع الفلزات القاعدية                                                      289
# أنشطة الخدمات المالية ، فيما عدا تمويل التأمين ...                       1220
# توصيل الكهرباء والغاز والبخار وتكييف الهواء                                54
# الأنشطة المساعدة لأنشطة الخدمات المالية وأنشطة ...                        689
# صنع منتجات المطاط واللدائن                                                313
# أنشطة الأمن والتحقيقات                                                    122
# الاتصالات                                                                 845
# أنشطة العمل الاجتماعي، دون إقامة                                         6179
# أنشطة المكاتب الرئيسية، والأنشطة الاستشارية في ...                       2384
# الصناعة التحويلية الأخرى                                                  978
# صُنع المشروبات                                                            148
# الأنشطة الرياضية وأنشطة التسلية والترفيه                                 7219
# صُنع الخشب ومنتجات الخشب والفلين ، باستثناء الأ...                        552
# صنع المعدات الكهربائية                                                    157
# الأنشطة القانونية وأنشطة المحاسبة                                        1470
# أنشطة خدمات المعلومات                                                    1122
# الأنشطة الأخرى للتعدين واستغلال المحاجر                                   103
# صناعة الآلات والمعدات غير المصنفة في موضع أخر                             109
# صُنع الورق ومنتجات الورق                                                  223
# وكالات السفر ومشغّلو الجولات السياحية وخدمات ال...                        619
# أنشطة المنظمات ذات العضوية                                               2647
# صُنع المنسوجات                                                            504
# صنع فحم الكوك والمنتجات النفطية المكررة                                   103
# النقل الجوي                                                              2422
# تجميع المياه ومعالجتها وتوصيلها                                            54
# الطباعة واستنساخ وسائط الأعلام المسجّلة                                   252
# أنشطة البريد ونقل الرسائل والطرود بواسطة مندوبين                          341
# الصرف الصحي                                                                70
# الأنشطة المهنية والعلمية والتقنية الأخرى                                 2352
# صناعة المركبات ذات المحركات والمركبات المقطورة ...                         61
# تمويل التأمين وإعادة التأمين وصناديق المعاشات ا...                        538
# أنشطة المعالجة وخدمات إدارة النفايات الأخرى                               694
# صنع المنتجات الصيدلانية الأساسية والمستحضرات ال...                        522
# صناعة معدات النقل الأخرى                                                   24
# أنشطة النشر                                                               496
# النقل المائي                                                              158
# صُنع المنتجات الجلدية والمنتجات ذات الصلة                                  23
# صنع الحواسيب والمنتجات الإلكترونية والبصرية                                81
# الرعاية مع الإقامة                                                       1259
# البحث والتطوير في المجال العلمي                                           213
# تعدين ركازات الفلزات                                                       19
# الأنشطة الإبداعية والفنون وأنشطة الترفيه                                  219
# الأنشطة البيطرية                                                          399
# أنشطة المكتبات والمحفوظات والمتاحف والأنشطة الث...                         37
# أنشطة البرمجة والإذاعة                                                     88
# تعدين الفحم والليغنيت                                                       1
# أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...                         10
# الحراجة وقطع الأخشاب                                                        0
# الأنشطة غير المتميزة لإنتاج السلع والخدمات التي...                          6
#
#                                                     total_employees
# Economic_Activity
# تشييد المباني                                               5445024
# تجارة التجزئة، باستثناء المركبات ذات المحركات و...          3540593
# أنشطة التشييد المتخصصة                                      2462404
# أنشطة خدمات الأطعمة والمشروبات                              2352124
# أنشطة تقديم الخدمات للمباني وتجميل المواقع                  2172423
# تجارة الجملة ، باستثناء المركبات ذات المحركات و...          2051842
# الهندسة المدنية                                             1831240
# الصحة البشرية                                               1244765
# أنشطة الاستخدام                                             1134086
# النقل البري و النقل عبر الأنابيب                            1125985
# تجارة الجملة والتجزئة ، وإصلاح المركبات ذات الم...          1102181
# الأنشطة الإيجارية                                            855954
# غير معرف                                                     768653
# صنع منتجات المعادن اللافلزية الأخرى                          654539
# التعليم                                                      627886
# صُنع المنتجات الغذائية                                       578742
# أنشطة الخدمات الشخصية الأخرى                                 543198
# الإدارة العامة والدفاع ؛ والضمان الاجتماعي الإل...           537537
# صيد الأسماك وتربية المائيات                                  536474
# صنع منتجات المعادن المشكلة ( باستثناء الآلات وا...           493567
# أنشطة زراعة المحاصيل والإنتاج الحيواني والصيد و...           438941
# التخزين وأنشطة الدعم للنقل                                   430004
# إصلاح أجهزة الحاسوب والسلع الشخصية والمنزلية                 338476
# أنشطة المعمارية والهندسية ، والاختبارات الفنية ...           335445
# صُنع المواد الكيميائية والمنتجات الكيميائية                  313907
# استخراج النفط الخام والغاز الطبيعي                           300090
# الإقامة                                                      269468
# أنشطة جمع النفايات ومعالجتها وتصريفها ، واسترجا...           251692
# الأنشطة العقارية                                             240121
# إصلاح وتركيب الآلات والمعدات                                 239398
# صُنع الملبوسات                                               221595
# أنشطة البرمجة الحاسوبية والخبرة الاستشارية وما ...           213613
# الأنشطة الإدارية للمكاتب ، وأنشطة الدعم للمكاتب...           196158
# أبحاث الإعلان والسوق                                         183044
# صنع الأثاث                                                   178739
# أنشطة خدمات دعم التعدين                                      169991
# صنع الفلزات القاعدية                                         169640
# أنشطة الخدمات المالية ، فيما عدا تمويل التأمين ...           165175
# توصيل الكهرباء والغاز والبخار وتكييف الهواء                  158587
# الأنشطة المساعدة لأنشطة الخدمات المالية وأنشطة ...           158017
# صنع منتجات المطاط واللدائن                                   146789
# أنشطة الأمن والتحقيقات                                       140011
# الاتصالات                                                    133675
# أنشطة العمل الاجتماعي، دون إقامة                             131047
# أنشطة المكاتب الرئيسية، والأنشطة الاستشارية في ...           108248
# الصناعة التحويلية الأخرى                                     108002
# صُنع المشروبات                                               107093
# الأنشطة الرياضية وأنشطة التسلية والترفيه                     101697
# صُنع الخشب ومنتجات الخشب والفلين ، باستثناء الأ...            96697
# صنع المعدات الكهربائية                                        95176
# الأنشطة القانونية وأنشطة المحاسبة                             92242
# أنشطة خدمات المعلومات                                         86851
# الأنشطة الأخرى للتعدين واستغلال المحاجر                       85881
# صناعة الآلات والمعدات غير المصنفة في موضع أخر                 83011
# صُنع الورق ومنتجات الورق                                      79687
# وكالات السفر ومشغّلو الجولات السياحية وخدمات ال...            79311
# أنشطة المنظمات ذات العضوية                                    76116
# صُنع المنسوجات                                                70925
# صنع فحم الكوك والمنتجات النفطية المكررة                       64956
# النقل الجوي                                                   53552
# تجميع المياه ومعالجتها وتوصيلها                               50452
# الطباعة واستنساخ وسائط الأعلام المسجّلة                       49022
# أنشطة البريد ونقل الرسائل والطرود بواسطة مندوبين              43184
# الصرف الصحي                                                   42211
# الأنشطة المهنية والعلمية والتقنية الأخرى                      39322
# صناعة المركبات ذات المحركات والمركبات المقطورة ...            34572
# تمويل التأمين وإعادة التأمين وصناديق المعاشات ا...            32404
# أنشطة المعالجة وخدمات إدارة النفايات الأخرى                   32403
# صنع المنتجات الصيدلانية الأساسية والمستحضرات ال...            31988
# صناعة معدات النقل الأخرى                                      27667
# أنشطة النشر                                                   27193
# النقل المائي                                                  16488
# صُنع المنتجات الجلدية والمنتجات ذات الصلة                     12209
# صنع الحواسيب والمنتجات الإلكترونية والبصرية                   12206
# الرعاية مع الإقامة                                            11010
# البحث والتطوير في المجال العلمي                               10768
# تعدين ركازات الفلزات                                           8273
# الأنشطة الإبداعية والفنون وأنشطة الترفيه                       8211
# الأنشطة البيطرية                                               8117
# أنشطة المكتبات والمحفوظات والمتاحف والأنشطة الث...             3938
# أنشطة البرمجة والإذاعة                                         3833
# تعدين الفحم والليغنيت                                           631
# أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل ...              296
# الحراجة وقطع الأخشاب                                            152
# الأنشطة غير المتميزة لإنتاج السلع والخدمات التي...              102

# %%
activity_group22.to_csv('data/activity_group22.csv', index=True)
activity_group23.to_csv('data/activity_group23.csv', index=True)
activity_group24.to_csv('data/activity_group24.csv', index=True)
